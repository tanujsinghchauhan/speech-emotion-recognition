# %%
pip install tensorflow

# %%
import librosa
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../dataset_metadata.csv")
print("Total samples:", len(df))
df.head()
# Out:
# Total samples: 1440
#                                            path  emotion     actor
# 0  ../dataset\Actor_01\03-01-01-01-01-01-01.wav  neutral  Actor_01
# 1  ../dataset\Actor_01\03-01-01-01-01-02-01.wav  neutral  Actor_01
# 2  ../dataset\Actor_01\03-01-01-01-02-01-01.wav  neutral  Actor_01
# 3  ../dataset\Actor_01\03-01-01-01-02-02-01.wav  neutral  Actor_01
# 4  ../dataset\Actor_01\03-01-02-01-01-01-01.wav     calm  Actor_01

# %%
def add_noise(audio):
    noise = np.random.normal(0,0.02, audio.shape)
    return audio + noise

def pitch_shift(audio, sr):
    return librosa.effects.pitch_shift(audio,sr=sr,n_steps=2)

def extract_logmel_from_audio(audio, sr):
    mel = librosa.feature.melspectrogram(
        y=audio,
        sr=sr,
        n_mels=128,
        hop_length=512
    )
    log_mel = librosa.power_to_db(mel, ref=np.max)
    return log_mel

# %%
#Extraction of spectogram dataset + adding padding
X=[]
y=[]
max_len = 128
for index, row in tqdm(df.iterrows(), total=len(df)):
    audio, sr = librosa.load(row["path"], sr=22050)
    #Original + Augmented versions
    variants = [audio, add_noise(audio), pitch_shift(audio, sr)]
    for variant in variants:
        spec = extract_logmel_from_audio(variant, sr)
        #pad or truncate for inputs to have identical shape
        if spec.shape[1] < max_len:
            pad_width = max_len - spec.shape[1]
            spec = np.pad(spec, pad_width=((0, 0), (0, pad_width)), mode='constant')
        else:
            spec = spec[:, :max_len]
        X.append(spec)
        y.append(row["emotion"])

X = np.array(X)
y = np.array(y)

print("Shape:",X.shape)
# Out:
# 100%|███████████████████████████████████████| 1440/1440 [06:18<00:00,  3.80it/s]
# Shape: (4320, 128, 128)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.imshow(X[0], aspect='auto', origin='lower')
plt.colorbar()
plt.title("Sample Spectrogram")
plt.show()

# %%
print("Min value:", np.min(X))
print("Max value:", np.max(X))
print("Mean value:", np.mean(X))
# Out:
# Min value: -80.0
# Max value: 0.0
# Mean value: -48.924500544037265

# %%
X = X[..., np.newaxis]
# for i in range(len(X)):
#     X[i] = (X[i] - np.min(X[i])) / (np.max(X[i]) - np.min(X[i]) + 1e-6)
# X = X/80.0
# mean = np.mean(X)
# std = np.std(X)

# X = (X - mean) / (std + 1e-6)
print("New Shape:", X.shape)
# Out:
# New Shape: (4320, 128, 128, 1)

# %%
#encoding labels
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)
print("Label Shape:", y_categorical.shape)
# Out:
# Label Shape: (4320, 8)

# %%
#train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, stratify=y_encoded, random_state=42)
print("Train:",X_train.shape)
print("Test:",X_test.shape)
# Out:
# Train: (3456, 128, 128, 1)
# Test: (864, 128, 128, 1)

# %%
#normalization
mean = np.mean(X_train)
std = np.std(X_train)

X_train = (X_train - mean) / (std + 1e-6)
X_test = (X_test - mean) / (std + 1e-6)

print("Train Mean:", np.mean(X_train))
print("Train Std:", np.std(X_train))
# Out:
# Train Mean: -6.728349873137747e-15
# Train Std: 0.999999956045106

# %%
#building the CNN model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# %%
model = Sequential([
    Input(shape=(128,128,1)),

    Conv2D(16, (3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    
    Flatten(),

    Dense(64, activation='relu',
          kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),

    Dense(8, activation='softmax')
])


model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape            ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 126, 126, 16)    │           160 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 63, 63, 16)      │             0 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 61, 61, 32)      │         4,640 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 30, 30, 32)      │             0 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 64)      │        18,496 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 14, 14, 64)      │             0 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 12544)           │             0 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)              │       802,880 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)              │             0 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)               │           520 │
# └─────────────────────────────────┴─────────────────────────┴───────────────┘
#  Total params: 826,696 (3.15 MB)
#  Trainable params: 826,696 (3.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#model compilation
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=40, batch_size=32, 
                   callbacks=[early_stop]
                   )
# Out:
# Epoch 1/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - accuracy: 0.1766 - loss: 2.0992 - val_accuracy: 0.2572 - val_loss: 1.9284
# Epoch 2/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.2815 - loss: 1.8729 - val_accuracy: 0.3483 - val_loss: 1.8173
# Epoch 3/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 114ms/step - accuracy: 0.3289 - loss: 1.7603 - val_accuracy: 0.4090 - val_loss: 1.6371
# Epoch 4/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - accuracy: 0.3546 - loss: 1.6997 - val_accuracy: 0.4061 - val_loss: 1.6244
# Epoch 5/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.4034 - loss: 1.6004 - val_accuracy: 0.4697 - val_loss: 1.4738
# Epoch 6/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - accuracy: 0.4110 - loss: 1.5512 - val_accuracy: 0.5043 - val_loss: 1.4363
# Epoch 7/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - accuracy: 0.4370 - loss: 1.4928 - val_accuracy: 0.4841 - val_loss: 1.4438
# Epoch 8/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.4729 - loss: 1.4094 - val_accuracy: 0.5462 - val_loss: 1.2894
# Epoch 9/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.5007 - loss: 1.3548 - val_accuracy: 0.5405 - val_loss: 1.3155
# Epoch 10/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.5072 - loss: 1.3157 - val_accuracy: 0.5867 - val_loss: 1.2303
# Epoch 11/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.5242 - loss: 1.2907 - val_accuracy: 0.6026 - val_loss: 1.1973
# Epoch 12/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.5481 - loss: 1.2373 - val_accuracy: 0.5882 - val_loss: 1.2489
# Epoch 13/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - accuracy: 0.5604 - loss: 1.1892 - val_accuracy: 0.6113 - val_loss: 1.1794
# Epoch 14/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 117ms/step - accuracy: 0.5767 - loss: 1.1631 - val_accuracy: 0.6431 - val_loss: 1.1318
# Epoch 15/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - accuracy: 0.5883 - loss: 1.1470 - val_accuracy: 0.6662 - val_loss: 1.0656
# Epoch 16/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.5894 - loss: 1.1350 - val_accuracy: 0.6387 - val_loss: 1.1158
# Epoch 17/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 141ms/step - accuracy: 0.6125 - loss: 1.0841 - val_accuracy: 0.6561 - val_loss: 1.0680
# Epoch 18/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - accuracy: 0.6122 - loss: 1.0955 - val_accuracy: 0.6647 - val_loss: 1.0401
# Epoch 19/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.6371 - loss: 1.0339 - val_accuracy: 0.6590 - val_loss: 1.1091
# Epoch 20/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.6331 - loss: 1.0408 - val_accuracy: 0.6604 - val_loss: 1.0191
# Epoch 21/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 131ms/step - accuracy: 0.6429 - loss: 1.0178 - val_accuracy: 0.6532 - val_loss: 1.0813
# Epoch 22/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - accuracy: 0.6357 - loss: 1.0276 - val_accuracy: 0.6749 - val_loss: 1.0380
# Epoch 23/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.6454 - loss: 0.9922 - val_accuracy: 0.6908 - val_loss: 0.9887
# Epoch 24/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.6545 - loss: 0.9694 - val_accuracy: 0.7038 - val_loss: 0.9859
# Epoch 25/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - accuracy: 0.6567 - loss: 0.9524 - val_accuracy: 0.6749 - val_loss: 1.0039
# Epoch 26/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.6617 - loss: 0.9507 - val_accuracy: 0.7153 - val_loss: 0.9774
# Epoch 27/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - accuracy: 0.6787 - loss: 0.9172 - val_accuracy: 0.6864 - val_loss: 1.0160
# Epoch 28/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - accuracy: 0.7015 - loss: 0.8977 - val_accuracy: 0.6806 - val_loss: 1.0205
# Epoch 29/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 10s 117ms/step - accuracy: 0.6870 - loss: 0.9342 - val_accuracy: 0.6922 - val_loss: 1.0694
# Epoch 30/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - accuracy: 0.6932 - loss: 0.8930 - val_accuracy: 0.7038 - val_loss: 0.9992
# Epoch 31/40
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7044 - loss: 0.8810 - val_accuracy: 0.6936 - val_loss: 1.0161

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7315 - loss: 0.9377
# Test Accuracy: 0.7314814925193787

# %%
#testing with audio sets
def predict_emotion(file_path, model, le, mean, std):
    
    # Load audio
    audio, sr = librosa.load(file_path, sr=22050)
    
    # Extract log-mel
    mel = librosa.feature.melspectrogram(
        y=audio,
        sr=sr,
        n_mels=128,
        hop_length=512
    )
    
    log_mel = librosa.power_to_db(mel, ref=np.max)
    
    # Pad or truncate
    max_len = 128
    
    if log_mel.shape[1] < max_len:
        pad_width = max_len - log_mel.shape[1]
        log_mel = np.pad(log_mel, ((0,0),(0,pad_width)), mode='constant')
    else:
        log_mel = log_mel[:, :max_len]
    
    # Add channel dimension
    log_mel = log_mel[..., np.newaxis]
    
    # Normalize using training mean/std
    log_mel = (log_mel - mean) / (std + 1e-6)
    
    # Add batch dimension
    log_mel = np.expand_dims(log_mel, axis=0)
    
    # Predict
    prediction = model.predict(log_mel)
    
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction)
    
    emotion = le.inverse_transform([predicted_class])[0]
    
    return emotion, confidence

# %%
#picking random audio from dataset
import random
from IPython.display import Audio, display

# Pick random file
random_index = random.randint(0, len(df)-1)
file_path = df.iloc[random_index]["path"]
actual_emotion = df.iloc[random_index]["emotion"]

print("Playing Audio:")
display(Audio(file_path))

# Predict using saved mean and std
predicted_emotion, confidence = predict_emotion(
    file_path,
    model,
    le,
    mean,
    std
)

print("\nFile:", file_path)
print("Actual Emotion:", actual_emotion)
print("Predicted Emotion:", predicted_emotion)
print("Confidence:", confidence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 from IPython.display import Audio, display
#       5 # Pick random file
# ----> 6 random_index = random.randint(0, len(df)-1)
#       7 file_path = df.iloc[random_index]["path"]
#       8 actual_emotion = df.iloc[random_index]["emotion"]
#
# NameError: name 'df' is not defined

# %%
audio, sr = librosa.load(file_path, sr=22050)
mel = librosa.feature.melspectrogram(y=audio, sr=sr, n_mels=128)
log_mel = librosa.power_to_db(mel, ref=np.max)

plt.figure(figsize=(6,4))
plt.imshow(log_mel, aspect='auto', origin='lower')
plt.colorbar()
plt.title(f"Spectrogram - Actual: {actual_emotion}")
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.show()

# %%
for i in range(5):
    random_index = random.randint(0, len(df)-1)
    file_path = df.iloc[random_index]["path"]
    actual = df.iloc[random_index]["emotion"]
    
    predicted, conf = predict_emotion(
        file_path,
        model,
        le,
        mean,
        std
    )
    
    print("\nActual:", actual)
    print("Predicted:", predicted)
    print("Confidence:", conf)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
#
# Actual: sad
# Predicted: sad
# Confidence: 0.6795965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
#
# Actual: disgust
# Predicted: disgust
# Confidence: 0.9895064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
#
# Actual: sad
# Predicted: sad
# Confidence: 0.8322337
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
#
# Actual: surprised
# Predicted: surprised
# Confidence: 0.47737336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
#
# Actual: fearful
# Predicted: fearful
# Confidence: 0.9969951

# %%
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np

# Predict on test set
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Get emotion labels
emotion_labels = le.classes_

# Classification report as dict
report_dict = classification_report(
    y_true,
    y_pred,
    target_names=emotion_labels,
    output_dict=True
)

# Convert to DataFrame
cnn_report_df = pd.DataFrame(report_dict).transpose()
cnn_report_df["Model"] = "CNN"

cnn_report_df.head()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step
#          precision    recall  f1-score  support Model
# angry     0.836364  0.800000  0.817778    115.0   CNN
# calm      0.705426  0.791304  0.745902    115.0   CNN
# disgust   0.803738  0.747826  0.774775    115.0   CNN
# fearful   0.787611  0.773913  0.780702    115.0   CNN
# happy     0.747475  0.643478  0.691589    115.0   CNN

# %%
cm = confusion_matrix(y_true, y_pred)

cm_data = []

for i, actual in enumerate(emotion_labels):
    for j, predicted in enumerate(emotion_labels):
        cm_data.append([
            actual,
            predicted,
            cm[i, j],
            "CNN"
        ])

cnn_cm_df = pd.DataFrame(
    cm_data,
    columns=["Actual", "Predicted", "Count", "Model"]
)

cnn_cm_df.head()
# Out:
#   Actual Predicted  Count Model
# 0  angry     angry     92   CNN
# 1  angry      calm      1   CNN
# 2  angry   disgust      6   CNN
# 3  angry   fearful      4   CNN
# 4  angry     happy      7   CNN

# %%
cnn_accuracy = model.evaluate(X_test, y_test, verbose=0)[1]

accuracy_df = pd.DataFrame({
    "Model": ["CNN"],
    "Accuracy": [cnn_accuracy]
})

accuracy_df
# Out:
#   Model  Accuracy
# 0   CNN  0.731481

# %%
cnn_report_df.to_csv("cnn_classification_report.csv")
cnn_cm_df.to_csv("cnn_confusion_matrix.csv", index=False)
accuracy_df.to_csv("model_accuracy.csv", index=False)
